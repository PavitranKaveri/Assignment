# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df=pd.read_csv("/Users/pavitrank/Downloads/college_1.csv")
df2=pd.read_csv("/Users/pavitrank/Downloads/college_2.csv")

# %%
df2.shape
# Out:
# (35, 9)

# %%
df.shape
# Out:
# (84, 7)

# %%
concat_data=pd.concat([df,df2])
concat_data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Exceeded_expectations=concat_data[concat_data['CodeKata Score']>15000]
Exceeded_expectations.to_csv(index=False)
# Out:
# 'Name,python,mysql,Previous Geekions,CodeKata Score,Department,Rising,python_en,computational_thinking\nA.Dharani,82.0,20.0,24500,24500,Computer Science and Engineering,0,,\nV.JEEVITHA ,82.0,20.0,21740,21740,Computer Science and Engineering,0,,\nHEMAVATHI.R,100.0,100.0,19680,19680,Computer Science and Engineering,0,,\nASHOK KUMAR K,100.0,31.0,19400,19400,Electronics and Electrical Engineering,0,0.0,9.0\n'

# %%
Reached_expectations=concat_data[(concat_data['CodeKata Score']<15000) & (concat_data['CodeKata Score']>10000)]
Reached_expectations.to_csv(index=False)

# %%
Needs_Improvement=concat_data[(concat_data['CodeKata Score']<10000) & (concat_data['CodeKata Score']>7000)]
Needs_Improvement.to_csv(index=False)

# %%
Unsatisfactory=concat_data[concat_data['CodeKata Score']<7000]
Unsatisfactory.to_csv(index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
print("Previous week geekions score is",concat_data['Previous Geekions'].mean())
print("This week geekions score is",concat_data['CodeKata Score'].mean())
# Out:
# Previous week geekions score is 3842.3529411764707
# This week geekions score is 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
concat_data['Name'].nunique()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
concat_data.sort_values(by=['CodeKata Score'],ascending=False).head(3)['Name']
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
concat_data.sort_values(by=['CodeKata Score'],ascending=False).head(3)['Name']

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
concat_data.groupby('Department').plot.pie(y='CodeKata Score')
# Out:
# Department
# Computer Science and Engineering             AxesSubplot(0.260833,0.125;0.503333x0.755)
# Electronics and Communication Engineering    AxesSubplot(0.260833,0.125;0.503333x0.755)
# Electronics and Electrical Engineering       AxesSubplot(0.260833,0.125;0.503333x0.755)
# dtype: object

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
concat_data.groupby('Department').max().plot('Name')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
concat_data.plot(kind='hist',x='Department',y='CodeKata Score')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x = [[0], [1]]

print(len(' '.join(list(map(str, x)))))
# Out:
# 7
